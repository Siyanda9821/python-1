# %%
nums=[3,8,10,12]
squares = []

for num in nums:
    squares.append(num**2)
print(squares)

# %%
nums = [3, 8, 10, 12]

squares=[num**2 for num in nums]
squares

# %%
odds = []
for i in range(50):
    if i%2 != 0:
        odds.append(i)
odds

# %%
odds = [i for i in range(50) if i%2 != 0]
odds

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
avengers = [
    "Hulk",
    "Iron man",
    "Black widow",
    "Captain america",
    "Spider man",
    "Thor",
]

avengers_letter_count = []

# Loop list & method
for i in range(len(avengers)):
    avengers_letter_count.append(len(avengers[i]))
    print(avengers_letter_count)
# Out:
# [4]
# [4, 8]
# [4, 8, 11]
# [4, 8, 11, 15]
# [4, 8, 11, 15, 10]
# [4, 8, 11, 15, 10, 4]

# %%
avengers = [
    "Hulk",
    "Iron man",
    "Black widow",
    "Captain america",
    "Spider man",
    "Thor",
]

avengers_letter_count = []

avengers_letter_count = [len(name) for name in avengers]
avengers_letter_count
# Out:
# [4, 8, 11, 15, 10, 4]

# %%
nums = [7,44,90,6,75,10]

print([num%2!=0 for num in nums])
    "Odd" else Even
# Out:
# [True, False, False, False, True, False]
