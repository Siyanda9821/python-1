# %%
import pandas as pd

# %% [markdown]
# ## Pandas
#
# - Analyse multidimensional data
# - Table like data
# - internally uses Numpy

# %%
tips_df=pd.read_csv('tips.csv')
tips_df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
weeknd = tips_df[(tips_df["day"] == "Saturday") | (tips_df["day"] == "Sunday")]
sorted = weeknd.sort_values(by="tip_percent", ascending=False)
sorted.loc[5:244].head()
# Out:
# <bound method NDFrame.head of Empty DataFrame
# Columns: [total_bill, tip, sex, smoker, day, time, size, tips+per+person, tip_percent]
# Index: []>

# %%
tips_df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
tips_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   sex         244 non-null    object
#  3   smoker      244 non-null    object
#  4   day         244 non-null    object
#  5   time        244 non-null    object
#  6   size        244 non-null    int64
# dtypes: float64(2), int64(1), object(4)
# memory usage: 13.5+ KB

# %%
tips_df.shape
# Out:
# (244, 7)

# %%
tips_df.columns
# Out:
# Index(['total_bill', 'tip', 'sex', 'smoker', 'day', 'time', 'size'], dtype='object')

# %%
tips_df.dtypes
# Out:
# total_bill    float64
# tip           float64
# sex            object
# smoker         object
# day            object
# time           object
# size            int64
# dtype: object

# %%
tips_df.describe()
# Out:
#        total_bill         tip        size
# count  244.000000  244.000000  244.000000
# mean    19.785943    2.998279    2.569672
# std      8.902412    1.383638    0.951100
# min      3.070000    1.000000    1.000000
# 25%     13.347500    2.000000    2.000000
# 50%     17.795000    2.900000    2.000000
# 75%     24.127500    3.562500    3.000000
# max     50.810000   10.000000    6.000000

# %%
tips_df.describe(include='all')
# Out:
#         total_bill         tip   sex smoker  day    time        size
# count   244.000000  244.000000   244    244  244     244  244.000000
# unique         NaN         NaN     2      2    4       2         NaN
# top            NaN         NaN  Male     No  Sat  Dinner         NaN
# freq           NaN         NaN   157    151   87     176         NaN
# mean     19.785943    2.998279   NaN    NaN  NaN     NaN    2.569672
# std       8.902412    1.383638   NaN    NaN  NaN     NaN    0.951100
# min       3.070000    1.000000   NaN    NaN  NaN     NaN    1.000000
# 25%      13.347500    2.000000   NaN    NaN  NaN     NaN    2.000000
# 50%      17.795000    2.900000   NaN    NaN  NaN     NaN    2.000000
# 75%      24.127500    3.562500   NaN    NaN  NaN     NaN    3.000000
# max      50.810000   10.000000   NaN    NaN  NaN     NaN    6.000000

# %%
tips_df[['day', 'time', 'tip']].head(10)
# Out:
#    day    time   tip
# 0  Sun  Dinner  1.01
# 1  Sun  Dinner  1.66
# 2  Sun  Dinner  3.50
# 3  Sun  Dinner  3.31
# 4  Sun  Dinner  3.61
# 5  Sun  Dinner  4.71
# 6  Sun  Dinner  2.00
# 7  Sun  Dinner  3.12
# 8  Sun  Dinner  1.96
# 9  Sun  Dinner  3.23

# %%
tips_df['tips+per+person']=tips_df["tip"] / tips_df["size"]
tips_df
# Out:
#      total_bill   tip     sex smoker   day    time  size  tips+per+person
# 0         16.99  1.01  Female     No   Sun  Dinner     2         0.505000
# 1         10.34  1.66    Male     No   Sun  Dinner     3         0.553333
# 2         21.01  3.50    Male     No   Sun  Dinner     3         1.166667
# 3         23.68  3.31    Male     No   Sun  Dinner     2         1.655000
# 4         24.59  3.61  Female     No   Sun  Dinner     4         0.902500
# ..          ...   ...     ...    ...   ...     ...   ...              ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3         1.973333
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2         1.000000
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2         1.000000
# 242       17.82  1.75    Male     No   Sat  Dinner     2         0.875000
# 243       18.78  3.00  Female     No  Thur  Dinner     2         1.500000
#
# [244 rows x 8 columns]

# %% [markdown]
# # Find the how much percentage people are tiping
#
# - Find tip percentage
# - Add it as another column - tip_percent
# - Round off to 2 decimal
# - `20.34` not be `0.243`

# %%
tip_percent = tips_df["tip"] / tips_df["total_bill"]*100
tip_percent
# Out:
# 0       5.944673
# 1      16.054159
# 2      16.658734
# 3      13.978041
# 4      14.680765
#          ...
# 239    20.392697
# 240     7.358352
# 241     8.822232
# 242     9.820426
# 243    15.974441
# Length: 244, dtype: float64

# %%
tips_df["tip_percent"] = tips_df["tip"] / tips_df["total_bill"] * 100
tips_df
# Out:
#      total_bill   tip     sex smoker   day    time  size  tips+per+person  \
# 0         16.99  1.01  Female     No   Sun  Dinner     2         0.505000
# 1         10.34  1.66    Male     No   Sun  Dinner     3         0.553333
# 2         21.01  3.50    Male     No   Sun  Dinner     3         1.166667
# 3         23.68  3.31    Male     No   Sun  Dinner     2         1.655000
# 4         24.59  3.61  Female     No   Sun  Dinner     4         0.902500
# ..          ...   ...     ...    ...   ...     ...   ...              ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3         1.973333
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2         1.000000
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2         1.000000
# 242       17.82  1.75    Male     No   Sat  Dinner     2         0.875000
# 243       18.78  3.00  Female     No  Thur  Dinner     2         1.500000
#
#      tip_percent
# 0       5.944673
# 1      16.054159
# 2      16.658734
# ...

# %% [markdown]
# ## Task 1
# - Filter the rows where people dined on a Sunday
# - Clue: Boolean matrix

# %%
tips_df[tips_df["day"]=="Sunday"]
# Out:
# Empty DataFrame
# Columns: [total_bill, tip, sex, smoker, day, time, size, tips+per+person, tip_percent]
# Index: []

# %% [markdown]
# ## Task 2
# Get the rows where person have tipped more than R3 on a Friday

# %%
gt3_fri2=tips_df[(tips_df["tip"] > 3) & (tips_df["day"] == "Friday")]
gt3_fri2
# Out:
# Empty DataFrame
# Columns: [total_bill, tip, sex, smoker, day, time, size, tips+per+person, tip_percent]
# Index: []

# %% [markdown]
# ## Task 3
# Extended task 2 top 5 tips on that Friday

# %%
gt3_fri2.sort_values(by="tip", ascending=False).head()
# Out:
# Empty DataFrame
# Columns: [total_bill, tip, sex, smoker, day, time, size, tips+per+person, tip_percent]
# Index: []

# %%
tips_df[(tips_df["size"] >=5) | (tips_df["total_bill"] >= 35)]
# Out:
#      total_bill    tip     sex smoker   day    time  size  tips+per+person  \
# 11        35.26   5.00  Female     No   Sun  Dinner     4         1.250000
# 23        39.42   7.58    Male     No   Sat  Dinner     4         1.895000
# 56        38.01   3.00    Male    Yes   Sat  Dinner     4         0.750000
# 59        48.27   6.73    Male     No   Sat  Dinner     4         1.682500
# 95        40.17   4.73    Male    Yes   Fri  Dinner     4         1.182500
# 102       44.30   2.50  Female    Yes   Sat  Dinner     3         0.833333
# 112       38.07   4.00    Male     No   Sun  Dinner     3         1.333333
# 125       29.80   4.20  Female     No  Thur   Lunch     6         0.700000
# 141       34.30   6.70    Male     No  Thur   Lunch     6         1.116667
# 142       41.19   5.00    Male     No  Thur   Lunch     5         1.000000
# 143       27.05   5.00  Female     No  Thur   Lunch     6         0.833333
# ...

# %%
tips_df.iloc[3]
# Out:
# total_bill             23.68
# tip                     3.31
# sex                     Male
# smoker                    No
# day                      Sun
# time                  Dinner
# size                       2
# tips+per+person        1.655
# tip_percent        13.978041
# Name: 3, dtype: object

# %%
tips_df.iloc[3:5]
# Out:
#    total_bill   tip     sex smoker  day    time  size  tips+per+person  \
# 3       23.68  3.31    Male     No  Sun  Dinner     2           1.6550
# 4       24.59  3.61  Female     No  Sun  Dinner     4           0.9025
#
#    tip_percent
# 3    13.978041
# 4    14.680765

# %%
tips_df.head(6)
# Out:
#    total_bill   tip     sex smoker  day    time  size  tips+per+person  \
# 0       16.99  1.01  Female     No  Sun  Dinner     2         0.505000
# 1       10.34  1.66    Male     No  Sun  Dinner     3         0.553333
# 2       21.01  3.50    Male     No  Sun  Dinner     3         1.166667
# 3       23.68  3.31    Male     No  Sun  Dinner     2         1.655000
# 4       24.59  3.61  Female     No  Sun  Dinner     4         0.902500
# 5       25.29  4.71    Male     No  Sun  Dinner     4         1.177500
#
#    tip_percent
# 0     5.944673
# 1    16.054159
# 2    16.658734
# 3    13.978041
# 4    14.680765
# 5    18.623962

# %%
tips_df.tail(6).loc[1]

# loc accepts a parameter (name)
#iloc takes the parameter (index)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~\AppData\Roaming\Python\Python310\site-packages\pandas\core\indexes\range.py:413, in RangeIndex.get_loc(self, key)
#     412 try:
# --> 413     return self._range.index(new_key)
#     414 except ValueError as err:
#
# ValueError: 1 is not in range
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[25], line 1
# ----> 1 tips_df.tail(6).loc[1]
#       3 # loc accepts a parameter (name)
#       4 #iloc takes the parameter (index)
#
# File ~\AppData\Roaming\Python\Python310\site-packages\pandas\core\indexing.py:1191, in _LocationIndexer.__getitem__(self, key)
#    1189 maybe_callable = com.apply_if_callable(key, self.obj)
#    1190 maybe_callable = self._check_deprecated_callable_usage(key, maybe_callable)
# ...

# %%
tips_df.loc[0:5,"tip":"size"]
# Out:
#     tip     sex smoker  day    time  size
# 0  1.01  Female     No  Sun  Dinner     2
# 1  1.66    Male     No  Sun  Dinner     3
# 2  3.50    Male     No  Sun  Dinner     3
# 3  3.31    Male     No  Sun  Dinner     2
# 4  3.61  Female     No  Sun  Dinner     4
# 5  4.71    Male     No  Sun  Dinner     4

# %%
tips_df.iloc[0:5, 1:7]
# Out:
#     tip     sex smoker  day    time  size
# 0  1.01  Female     No  Sun  Dinner     2
# 1  1.66    Male     No  Sun  Dinner     3
# 2  3.50    Male     No  Sun  Dinner     3
# 3  3.31    Male     No  Sun  Dinner     2
# 4  3.61  Female     No  Sun  Dinner     4

# %%
tips_df.iloc[0:5, 1]
# Out:
# 0    1.01
# 1    1.66
# 2    3.50
# 3    3.31
# 4    3.61
# Name: tip, dtype: float64

# %%
tips_df.iloc[0:5, [1,6]]
# Out:
#     tip  size
# 0  1.01     2
# 1  1.66     3
# 2  3.50     3
# 3  3.31     2
# 4  3.61     4

# %%
tips_df.loc[ 0:244,'tip':'day']
# Out:
#       tip     sex smoker   day
# 0    1.01  Female     No   Sun
# 1    1.66    Male     No   Sun
# 2    3.50    Male     No   Sun
# 3    3.31    Male     No   Sun
# 4    3.61  Female     No   Sun
# ..    ...     ...    ...   ...
# 239  5.92    Male     No   Sat
# 240  2.00  Female    Yes   Sat
# 241  2.00    Male    Yes   Sat
# 242  1.75    Male     No   Sat
# 243  3.00  Female     No  Thur
#
# [244 rows x 4 columns]

# %%
tips_df.iloc[0:244, 1:5]
# Out:
#       tip     sex smoker   day
# 0    1.01  Female     No   Sun
# 1    1.66    Male     No   Sun
# 2    3.50    Male     No   Sun
# 3    3.31    Male     No   Sun
# 4    3.61  Female     No   Sun
# ..    ...     ...    ...   ...
# 239  5.92    Male     No   Sat
# 240  2.00  Female    Yes   Sat
# 241  2.00    Male    Yes   Sat
# 242  1.75    Male     No   Sat
# 243  3.00  Female     No  Thur
#
# [244 rows x 4 columns]

# %% [markdown]
# ## Task 1
# Retrieve and list the entries, sorting them from highest to lowest by `tip_percent`, excluding the first five results, specifically for weekends (Saturday and Sunday).

# %%
rank = tips_df.sort_values(by="tip_percent", ascending=False)
rank1 = rank[(rank["day"] == "Sun") | (rank["day"] == "Sat")].loc[5:, :]
rank1
# Out:
#      total_bill   tip     sex smoker  day    time  size  tips+per+person  \
# 5         25.29  4.71    Male     No  Sun  Dinner     4         1.177500
# 212       48.33  9.00    Male     No  Sat  Dinner     4         2.250000
# 218        7.74  1.44    Male    Yes  Sat  Dinner     2         0.720000
# 47        32.40  6.00    Male     No  Sun  Dinner     4         1.500000
# 44        30.40  5.60    Male     No  Sun  Dinner     4         1.400000
# ..          ...   ...     ...    ...  ...     ...   ...              ...
# 187       30.46  2.00    Male    Yes  Sun  Dinner     5         0.400000
# 0         16.99  1.01  Female     No  Sun  Dinner     2         0.505000
# 57        26.41  1.50  Female     No  Sat  Dinner     2         0.750000
# 102       44.30  2.50  Female    Yes  Sat  Dinner     3         0.833333
# 237       32.83  1.17    Male    Yes  Sat  Dinner     2         0.585000
#
#      tip_percent
# 5      18.623962
# 212    18.621974
# 218    18.604651
# 47     18.518519
# ...

# %%
weeknd =tips_df[(tips_df["day"] == "Sat") | (tips_df["day"] == "Sun")]
sorted=weeknd.sort_values(by='tip_percent' ,ascending=False)
sorted.loc[5:244]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Roaming\Python\Python310\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:2606, in pandas._libs.hashtable.Int64HashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:2630, in pandas._libs.hashtable.Int64HashTable.get_item()
#
# KeyError: 244
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[57], line 3
# ...

# %%
sorted.shape
# Out:
# (0, 9)

# %%
print(sorted)
# Out:
# Empty DataFrame
# Columns: [total_bill, tip, sex, smoker, day, time, size, tips+per+person, tip_percent]
# Index: []

# %%
thur = tips_df[(tips_df["size"] > 3) & (tips_df["day"] == "Thur")&(tips_df["time"]=="Lunch")]
sorted1 = thur.sort_values(by="tip", ascending=False)
sorted1.iloc[1:3]
# Out:
#      total_bill   tip     sex smoker   day   time  size  tips+per+person  \
# 85        34.83  5.17  Female     No  Thur  Lunch     4           1.2925
# 197       43.11  5.00  Female    Yes  Thur  Lunch     4           1.2500
#
#      tip_percent
# 85     14.843526
# 197    11.598237

# %%
tips_df.describe()
# Out:
#        total_bill         tip        size  tips+per+person  tip_percent
# count  244.000000  244.000000  244.000000       244.000000   244.000000
# mean    19.785943    2.998279    2.569672         1.212762    16.080258
# std      8.902412    1.383638    0.951100         0.491705     6.107220
# min      3.070000    1.000000    1.000000         0.400000     3.563814
# 25%     13.347500    2.000000    2.000000         0.862500    12.912736
# 50%     17.795000    2.900000    2.000000         1.107500    15.476977
# 75%     24.127500    3.562500    3.000000         1.500000    19.147549
# max     50.810000   10.000000    6.000000         3.333333    71.034483

# %%
tips_df[["tip", "total_bill"]].mean()
# Out:
# tip            2.998279
# total_bill    19.785943
# dtype: float64

# %% [markdown]
# ## Summarising
#
# - average of total bill on each day ()
# ```sql
# select avg(total_bill) as average_total_bill
# from tips_df
# group by 'day';
#
# ```

# %%
tips_df.groupby('day')['total_bill'].mean()
# Out:
# day
# Fri     17.151579
# Sat     20.441379
# Sun     21.410000
# Thur    17.682742
# Name: total_bill, dtype: float64

# %% [markdown]
# ## Task 2.1
# Who leaves more tip Smoker vs Non-Smoker by Total

# %%
tips_df.groupby('smoker')['tip'].sum()
# Out:
# smoker
# No     451.77
# Yes    279.81
# Name: tip, dtype: float64

# %% [markdown]
# # Task 2.2
# Who leaves more tip Smoker vs Non-Smoker on an average

# %%
tips_df.groupby("smoker")["tip"].mean()
# Out:
# smoker
# No     2.991854
# Yes    3.008710
# Name: tip, dtype: float64

# %% [markdown]
# ### Aggregate

# %%
tips_df.groupby("smoker").aggregate({'tip':['mean','sum'],'total_bill':['mean','sum']})
# Out:
#              tip         total_bill
#             mean     sum       mean      sum
# smoker
# No      2.991854  451.77  19.188278  2897.43
# Yes     3.008710  279.81  20.756344  1930.34

# %% [markdown]
# ## Task 3
# Based on the day calculate total of total_bill and on average what is tip_percent

# %%
tips_df.groupby("day").aggregate(
    {"total_bill": ["sum"], "tip_percent": ["mean"]}
)
# Out:
#      total_bill tip_percent
#             sum        mean
# day
# Fri      325.88   16.991303
# Sat     1778.40   15.315172
# Sun     1627.16   16.689729
# Thur    1096.33   16.127563

# %%
tips_df.groupby(["smoker",'day'])["tip"].mean()
# Out:
# smoker  day
# No      Fri     2.812500
#         Sat     3.102889
#         Sun     3.167895
#         Thur    2.673778
# Yes     Fri     2.714000
#         Sat     2.875476
#         Sun     3.516842
#         Thur    3.030000
# Name: tip, dtype: float64

# %%
tips_df.groupby(["sex",'day'])["tip"].mean()
# Out:
# sex     day
# Female  Fri     2.781111
#         Sat     2.801786
#         Sun     3.367222
#         Thur    2.575625
# Male    Fri     2.693000
#         Sat     3.083898
#         Sun     3.220345
#         Thur    2.980333
# Name: tip, dtype: float64

# %%
tips_df.groupby(["day", "sex"])["tip"].mean().unstack()

## Unstack transforms the results by creating columns
# Out:
# sex     Female      Male
# day
# Fri   2.781111  2.693000
# Sat   2.801786  3.083898
# Sun   3.367222  3.220345
# Thur  2.575625  2.980333

# %% [markdown]
# ## Task 2
# On an average, max, min who (male or female) earns more tip each day

# %%
tips_df.groupby(["sex",'day']).aggregate({"tip": ['max','min','mean']})
# Out:
#                tip
#                max   min      mean
# sex    day
# Female Fri    4.30  1.00  2.781111
#        Sat    6.50  1.00  2.801786
#        Sun    5.20  1.01  3.367222
#        Thur   5.17  1.25  2.575625
# Male   Fri    4.73  1.50  2.693000
#        Sat   10.00  1.00  3.083898
#        Sun    6.50  1.32  3.220345
#        Thur   6.70  1.44  2.980333

# %%
tips_df.groupby(["day", "sex"]).aggregate({"tip": ["mean", "max", "min"]}).unstack()
# Out:
#            tip
#           mean              max           min
# sex     Female      Male Female   Male Female  Male
# day
# Fri   2.781111  2.693000   4.30   4.73   1.00  1.50
# Sat   2.801786  3.083898   6.50  10.00   1.00  1.00
# Sun   3.367222  3.220345   5.20   6.50   1.01  1.32
# Thur  2.575625  2.980333   5.17   6.70   1.25  1.44

# %%
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %%
tips_df
# Out:
#      total_bill   tip     sex smoker   day    time  size  tips+per+person  \
# 0         16.99  1.01  Female     No   Sun  Dinner     2         0.505000
# 1         10.34  1.66    Male     No   Sun  Dinner     3         0.553333
# 2         21.01  3.50    Male     No   Sun  Dinner     3         1.166667
# 3         23.68  3.31    Male     No   Sun  Dinner     2         1.655000
# 4         24.59  3.61  Female     No   Sun  Dinner     4         0.902500
# ..          ...   ...     ...    ...   ...     ...   ...              ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3         1.973333
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2         1.000000
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2         1.000000
# 242       17.82  1.75    Male     No   Sat  Dinner     2         0.875000
# 243       18.78  3.00  Female     No  Thur  Dinner     2         1.500000
#
#      tip_percent
# 0       5.944673
# 1      16.054159
# 2      16.658734
# ...

# %%
from turtle import color


y_axis=tips_df['tip'].head()
x_axis = y_axis.index+1
plt.bar(x_axis,y_axis,color="plum",alpha=0.8)
# plt.bar(x_axis,y_axis)
plt.xlabel('Days')
plt.title('Tips on the first 5 days')
# Out:
# Text(0.5, 1.0, 'Tips on the first 5 days')

# %%
y_axis=tips_df['total_bill']
plt.bar(x_axis, y_axis, color="plum", alpha=0.8)
plt.xlabel("Days")
plt.title("Tips on the first 5 days")

# %%
y=tips_df.groupby(["day"]).aggregate({"total_bill": ["mean"]})
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Roaming\Python\Python310\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'day'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[104], line 2
# ...

# %%
y_axis = tips_df["total_bill"]
x_axis = y_axis.index + 1
plt.bar(x_axis,y_axis)
# Out:
# <BarContainer object of 244 artists>

# %%
y_axis = tips_df.groupby(["day"])["total_bill"].mean()
x_axis=y_axis.index

# plt.bar(x_axis,y_axis)
plt.bar(x_axis,y_axis)
# Out:
# <BarContainer object of 4 artists>

# %% [markdown]
# ## Task: Proportion of Meals
# Create a pie chart comparing how many times people visited on which time of the day (Dinner, Lunch)

# %%
y=tips_df.groupby(["time"])["size"].count()


y.plot(kind="pie", autopct="%1.2f", title="Number of visits")
# Out:
# <Axes: title={'center': 'Number of visits'}, ylabel='size'>

# %%
tips_df.groupby(["time"])["size"].count()
# Out:
# time
# Dinner    176
# Lunch      68
# Name: size, dtype: int64

# %%
from turtle import color


y_axis = tips_df["tip"].head()

# x_axis = y_axis.index + 1
# plt.bar(x_axis, y_axis, color="plum", alpha=0.8)
# # plt.bar(x_axis,y_axis)
# plt.xlabel("Days")
# plt.title("Tips on the first 5 days")

sns.barplot(x='day',y='total_bill', data=tips_df, palette='pastel')
# Out:
# C:\Users\E1009821\AppData\Local\Temp\ipykernel_11216\954254050.py:12: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='day',y='total_bill', data=tips_df, palette='pastel')
# <Axes: xlabel='day', ylabel='total_bill'>
